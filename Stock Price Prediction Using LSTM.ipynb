# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/dist-packages (0.2.12)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.3.5)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from yfinance) (39.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import math
import numpy as np
import yfinance as yf
import pandas as pd
from pandas_datareader import data as pdr

# %%
yf.pdr_override()

df = pdr.get_data_yahoo('AAPL', start = '2012-01-01', end = '2023-03-15')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High  ...   Adj Close     Volume
# Date                                ...
# 2012-01-03   14.621429   14.732143  ...   12.500196  302220800
# 2012-01-04   14.642857   14.810000  ...   12.567370  260022000
# 2012-01-05   14.819643   14.948214  ...   12.706890  271269600
# 2012-01-06   14.991786   15.098214  ...   12.839730  318292800
# 2012-01-09   15.196429   15.276786  ...   12.819364  394024400
# ...                ...         ...  ...         ...        ...
# 2023-03-08  152.809998  153.470001  ...  152.869995   47204800
# 2023-03-09  153.559998  154.539993  ...  150.589996   53833600
# 2023-03-10  150.210007  150.940002  ...  148.500000   68524400
# 2023-03-13  147.809998  153.139999  ...  150.470001   84457100
# 2023-03-14  151.279999  153.399994  ...  152.589996   73695900
#
# [2817 rows x 6 columns]

# %%
df.shape
# Out:
# (2817, 6)
# (2817, 6)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (12,6))
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Closing Price USD')
plt.show()

# %%
data = df.filter(['Close'])

dataset = data.values

training_data_len = math.ceil(len(dataset)* .8)
training_data_len
# Out:
# 2254

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00439887],
#        [0.00486851],
#        [0.00584391],
#        ...,
#        [0.80060992],
#        [0.81233176],
#        [0.82494608]])

# %%
train_data = scaled_data[:training_data_len, :]
train_data.shape
# Out:
# (2254, 1)

# %%
x_train = []
y_train = []

for i in range(60, len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])
  if i <= 61:
    print(x_train)
    print(y_train)
    print()
# Out:
# [array([0.00439887, 0.00486851, 0.00584391, 0.00677256, 0.00663019,
#        0.00695107, 0.00680444, 0.00655793, 0.00622217, 0.00726133,
#        0.00819848, 0.00790947, 0.0063263 , 0.00783722, 0.00634968,
#        0.01192796, 0.01149658, 0.01205972, 0.01327737, 0.01401476,
#        0.01395314, 0.01372576, 0.01469479, 0.01560643, 0.01663922,
#        0.01830739, 0.02181161, 0.02186474, 0.02381555, 0.02527333,
#        0.0227679 , 0.02373267, 0.02371354, 0.02641875, 0.02603411,
#        0.026746  , 0.02802528, 0.02873719, 0.03078787, 0.03228178,
#        0.03271317, 0.03286405, 0.03030973, 0.02969346, 0.02978484,
#        0.03218616, 0.03286193, 0.03431335, 0.03773469, 0.04229932,
#        0.04144504, 0.04144716, 0.04474738, 0.04578017, 0.04504489,
#        0.04437338, 0.04367423, 0.04599691, 0.04759072, 0.04825798])]
# [0.04660893460974819]
#
# [array([0.00439887, 0.00486851, 0.00584391, 0.00677256, 0.00663019,
#        0.00695107, 0.00680444, 0.00655793, 0.00622217, 0.00726133,
#        0.00819848, 0.00790947, 0.0063263 , 0.00783722, 0.00634968,
#        0.01192796, 0.01149658, 0.01205972, 0.01327737, 0.01401476,
#        0.01395314, 0.01372576, 0.01469479, 0.01560643, 0.01663922,
#        0.01830739, 0.02181161, 0.02186474, 0.02381555, 0.02527333,
#        0.0227679 , 0.02373267, 0.02371354, 0.02641875, 0.02603411,
#        0.026746  , 0.02802528, 0.02873719, 0.03078787, 0.03228178,
#        0.03271317, 0.03286405, 0.03030973, 0.02969346, 0.02978484,
#        0.03218616, 0.03286193, 0.03431335, 0.03773469, 0.04229932,
#        0.04144504, 0.04144716, 0.04474738, 0.04578017, 0.04504489,
#        0.04437338, 0.04367423, 0.04599691, 0.04759072, 0.04825798]), array([0.00486851, 0.00584391, 0.00677256, 0.00663019, 0.00695107,
#        0.00680444, 0.00655793, 0.00622217, 0.00726133, 0.00819848,
#        0.00790947, 0.0063263 , 0.00783722, 0.00634968, 0.01192796,
#        0.01149658, 0.01205972, 0.01327737, 0.01401476, 0.01395314,
#        0.01372576, 0.01469479, 0.01560643, 0.01663922, 0.01830739,
#        0.02181161, 0.02186474, 0.02381555, 0.02527333, 0.0227679 ,
#        0.02373267, 0.02371354, 0.02641875, 0.02603411, 0.026746  ,
#        0.02802528, 0.02873719, 0.03078787, 0.03228178, 0.03271317,
#        0.03286405, 0.03030973, 0.02969346, 0.02978484, 0.03218616,
#        0.03286193, 0.03431335, 0.03773469, 0.04229932, 0.04144504,
#        0.04144716, 0.04474738, 0.04578017, 0.04504489, 0.04437338,
#        0.04367423, 0.04599691, 0.04759072, 0.04825798, 0.04660893])]
# [0.04660893460974819, 0.04441800167645807]

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))
x_train.shape
# Out:
# (2194, 60, 1)

# %%
from keras.layers import Dense, LSTM
from keras.models import Sequential

model = Sequential()

model.add(LSTM(50, return_sequences= True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50,return_sequences= False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size = 64, epochs = 50)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 10s 101ms/step - loss: 0.0057
# Epoch 2/50
# 35/35 [==============================] - 3s 87ms/step - loss: 3.5708e-04
# Epoch 3/50
# 35/35 [==============================] - 3s 71ms/step - loss: 1.8476e-04
# Epoch 4/50
# 35/35 [==============================] - 2s 71ms/step - loss: 1.6400e-04
# Epoch 5/50
# 35/35 [==============================] - 3s 74ms/step - loss: 1.6431e-04
# Epoch 6/50
# 35/35 [==============================] - 4s 110ms/step - loss: 1.5422e-04
# Epoch 7/50
# 35/35 [==============================] - 3s 80ms/step - loss: 1.7599e-04
# Epoch 8/50
# 35/35 [==============================] - 3s 73ms/step - loss: 1.7352e-04
# Epoch 9/50
# 35/35 [==============================] - 3s 73ms/step - loss: 1.4886e-04
# Epoch 10/50
# 35/35 [==============================] - 3s 74ms/step - loss: 1.4300e-04
# Epoch 11/50
# 35/35 [==============================] - 4s 116ms/step - loss: 1.4222e-04
# Epoch 12/50
# 35/35 [==============================] - 3s 76ms/step - loss: 1.4722e-04
# Epoch 13/50
# 35/35 [==============================] - 3s 74ms/step - loss: 1.4763e-04
# Epoch 14/50
# 35/35 [==============================] - 3s 74ms/step - loss: 1.2661e-04
# Epoch 15/50
# 35/35 [==============================] - 3s 89ms/step - loss: 1.2825e-04
# Epoch 16/50
# 35/35 [==============================] - 4s 101ms/step - loss: 1.1962e-04
# Epoch 17/50
# 35/35 [==============================] - 3s 75ms/step - loss: 1.1314e-04
# Epoch 18/50
# 35/35 [==============================] - 3s 75ms/step - loss: 1.1106e-04
# Epoch 19/50
# 35/35 [==============================] - 3s 75ms/step - loss: 1.1551e-04
# Epoch 20/50
# 35/35 [==============================] - 4s 110ms/step - loss: 1.3546e-04
# Epoch 21/50
# 35/35 [==============================] - 3s 83ms/step - loss: 1.1320e-04
# Epoch 22/50
# 35/35 [==============================] - 3s 75ms/step - loss: 1.2583e-04
# Epoch 23/50
# 35/35 [==============================] - 3s 75ms/step - loss: 1.0935e-04
# Epoch 24/50
# 35/35 [==============================] - 3s 79ms/step - loss: 1.0393e-04
# Epoch 25/50
# 35/35 [==============================] - 4s 113ms/step - loss: 1.1244e-04
# Epoch 26/50
# 35/35 [==============================] - 3s 75ms/step - loss: 1.0902e-04
# Epoch 27/50
# 35/35 [==============================] - 3s 76ms/step - loss: 1.0588e-04
# Epoch 28/50
# 35/35 [==============================] - 3s 76ms/step - loss: 9.2857e-05
# Epoch 29/50
# 35/35 [==============================] - 3s 96ms/step - loss: 1.0009e-04
# Epoch 30/50
# 35/35 [==============================] - 3s 95ms/step - loss: 9.1972e-05
# Epoch 31/50
# 35/35 [==============================] - 3s 79ms/step - loss: 1.0021e-04
# Epoch 32/50
# 35/35 [==============================] - 3s 77ms/step - loss: 9.7718e-05
# Epoch 33/50
# 35/35 [==============================] - 3s 77ms/step - loss: 1.0040e-04
# Epoch 34/50
# 35/35 [==============================] - 4s 117ms/step - loss: 8.7216e-05
# Epoch 35/50
# 35/35 [==============================] - 3s 76ms/step - loss: 8.8792e-05
# Epoch 36/50
# 35/35 [==============================] - 3s 77ms/step - loss: 1.0156e-04
# Epoch 37/50
# 35/35 [==============================] - 3s 77ms/step - loss: 8.2405e-05
# Epoch 38/50
# 35/35 [==============================] - 3s 96ms/step - loss: 9.3328e-05
# Epoch 39/50
# 35/35 [==============================] - 3s 99ms/step - loss: 9.0726e-05
# Epoch 40/50
# 35/35 [==============================] - 3s 76ms/step - loss: 7.5581e-05
# Epoch 41/50
# 35/35 [==============================] - 3s 77ms/step - loss: 7.8209e-05
# Epoch 42/50
# 35/35 [==============================] - 3s 76ms/step - loss: 8.9676e-05
# Epoch 43/50
# 35/35 [==============================] - 4s 117ms/step - loss: 9.1655e-05
# Epoch 44/50
# 35/35 [==============================] - 3s 75ms/step - loss: 8.2757e-05
# Epoch 45/50
# 35/35 [==============================] - 3s 77ms/step - loss: 7.5502e-05
# Epoch 46/50
# 35/35 [==============================] - 3s 77ms/step - loss: 7.6189e-05
# Epoch 47/50
# 35/35 [==============================] - 3s 90ms/step - loss: 9.7760e-05
# Epoch 48/50
# 35/35 [==============================] - 4s 104ms/step - loss: 6.9396e-05
# Epoch 49/50
# 35/35 [==============================] - 3s 78ms/step - loss: 7.6872e-05
# Epoch 50/50
# 35/35 [==============================] - 3s 76ms/step - loss: 7.2799e-05

# %%
test_data = scaled_data[training_data_len - 60: , :]

#create x_test and y_test
x_test = []
y_test = dataset[training_data_len: , :]

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i , 0])

# %%
x_test = np.array(x_test)
x_test.shape
# Out:
# (563, 60)

# %%
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1], 1))

# x_test = np.reshape(x_test, (563,60, 1))
x_test.shape
# Out:
# (563, 60, 1)

# %%
predictions = model.predict(x_test)

predictions = scaler.inverse_transform(predictions)
# Out:
# 18/18 [==============================] - 2s 19ms/step

# %%
rmse = np.sqrt(np.mean(((predictions - y_test)**2)))
rmse
# Out:
# 5.615238518026153

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Out:
# <ipython-input-32-8f78faa8f9ca>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
plt.figure(figsize = (12,6))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price USD')
plt.plot(train['Close'])
plt.plot(valid[['Close' , 'Predictions']])
plt.legend(['Train','Val','Predictions'], loc= 'lower right')
plt.show()

# %%
valid
# Out:
#                  Close  Predictions
# Date
# 2020-12-16  127.809998   121.276077
# 2020-12-17  128.699997   122.706131
# 2020-12-18  126.660004   124.226830
# 2020-12-21  128.229996   124.884430
# 2020-12-22  131.880005   125.420570
# ...                ...          ...
# 2023-03-08  152.869995   147.031631
# 2023-03-09  150.589996   148.355194
# 2023-03-10  148.500000   148.494629
# 2023-03-13  150.470001   147.499680
# 2023-03-14  152.589996   146.811478
#
# [563 rows x 2 columns]
